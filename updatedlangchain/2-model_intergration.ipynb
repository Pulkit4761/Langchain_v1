# %% [markdown]
# ## Models integration with OpenAI, Gemini and Groq

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(output_version=None, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x0000023BC2978830>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000023BC29792B0>, root_client=<openai.OpenAI object at 0x0000023BC1C8FB60>, root_async_client=<openai.AsyncOpenAI object at 0x0000023BC2979010>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True, stream_chunk_timeout=120.0)

# %%
## invoke the model
response=model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content="Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 12, 'total_tokens': 42, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_cdf1701fdc', 'id': 'chatcmpl-DoZSkHXEj037FbMV0XgFN9vJNJS7K', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ea899-6d7f-7e91-a0d1-4955c8c9539d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 30, 'total_tokens': 42, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
### ChatOpenAI

from langchain_openai import ChatOpenAI
model=ChatOpenAI(model="gpt-4.1")
response=model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content='Hello! I’m just a virtual assistant, so I don’t have feelings, but I’m here and ready to help you. How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 12, 'total_tokens': 45, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_cdf1701fdc', 'id': 'chatcmpl-DoZXkkVF2uy2D4iQ5IzpNjxnAcJnf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ea89e-2e1b-7201-a516-61c5a1509852-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 33, 'total_tokens': 45, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
response.content
# Out:
# "Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?"

# %% [markdown]
# ### Google Gemini Model Intergration

# %%
import os
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-2.5-flash")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# 'Parrots talk due to a fascinating combination of unique anatomy, high intelligence, and strong social drives. It\'s not quite "talking" in the human sense of understanding complex language, but rather an impressive form of **vocal mimicry** and **contextual association**.\n\nHere are the key reasons why parrots talk:\n\n1.  **Unique Vocal Anatomy:**\n    *   **Syrinx:** Unlike humans who have a larynx, birds have a syrinx, a complex vocal organ located at the base of the trachea. Parrots have an exceptionally flexible syrinx with more muscles and control than most other birds, allowing them to produce a wide range of sounds, including mimicking human speech.\n    *   **Tongue:** Parrots also possess a thick, muscular, and agile tongue, which they can manipulate to articulate sounds in a way similar to how humans use their tongues for speech.\n\n2.  **Vocal Learning & Specialized Brain Structures:**\n    *   Parrots are one of the few groups of animals (along with songbirds and hummingbirds) that exhibit **vocal learning**. This means they can learn to produce new sounds by imitating what they hear, rather than just relying on innate vocalizations.\n    *   They have specialized brain regions dedicated to vocal learning and production. These "song control nuclei" in their brains allow them to process and replicate sounds with remarkable accuracy.\n\n3.  **Social Nature & Mimicry:**\n    *   **Flock Animals:** Parrots are highly social creatures that live in large flocks in the wild. Vocalizations are crucial for communication within these flocks – for identifying individuals, warning of predators, coordinating foraging, and maintaining social bonds.\n    *   **Integration and Bonding:** In a human household, a parrot often views its human caregivers as its "flock." Mimicking human sounds is a way for them to try and integrate, communicate, and bond with their human companions. It\'s a way of "fitting in" and being part of the social group.\n    *   **Attention Seeking:** Talking and mimicking can also be a way for parrots to get attention from their humans, which is a powerful motivator for any social animal.\n\n4.  **High Intelligence & Contextual Understanding:**\n    *   Parrots, particularly species like African Grey Parrots, are highly intelligent animals. They are capable of problem-solving and can associate specific sounds or words with certain objects, actions, or situations.\n    *   For example, a parrot might learn to say "hello" when someone enters the room, "bye-bye" when they leave, or "want a cracker" when it sees a treat. While they don\'t understand the abstract grammar or syntax of human language, they can learn to use words appropriately within specific contexts.\n\n5.  **Boredom and Enrichment:**\n    *   In captivity, parrots often have a lot of mental energy and curiosity. Vocal mimicry can serve as a form of self-entertainment and mental stimulation, especially when they are left alone.\n\n**In summary:** Parrots talk because they possess the unique physical machinery to produce diverse sounds, a specialized brain for vocal learning, and a strong social drive to communicate and bond with their "flock" (whether avian or human). While their "talking" is primarily mimicry and contextual association, it\'s an incredible display of their cognitive and social abilities.'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='Parrots talk for a fascinating combination of reasons, stemming from their biology, social nature, and cognitive abilities. Here\'s a breakdown of why they do it:\n\n**1. Social Bonding and Communication:**\n\n* **Flock Animals:** Parrots are highly social creatures that live in large flocks in the wild. Communication is vital for their survival and social cohesion. Talking, or vocalizing in general, is their primary way of interacting with each other.\n* **Maintaining Contact:** In dense forests or when foraging, parrots use calls to stay in touch with their flock members, alert them to danger, and coordinate movements.\n* **Establishing Hierarchy and Social Status:** Vocalizations can also play a role in establishing dominance and social order within a flock.\n* **Pair Bonding:** Parrots form strong pair bonds, and vocalizations are a key part of their courtship and communication within these partnerships.\n\n**2. Mimicry as a Survival Tool (in the wild):**\n\n* **Learning Their Own Species\' Calls:** Young parrots learn the specific calls and vocalizations of their own species and their individual flock through listening and repetition. This is crucial for being recognized and accepted by their group.\n* **Alarm Calls:** Mimicking the alarm calls of other species can be a survival advantage, allowing them to react to threats that might not be obvious to them otherwise.\n* **Camouflage (to some extent):** While not direct mimicry of human speech, some researchers believe that the ability to mimic sounds in their environment could offer a slight form of camouflage by blending in with the ambient noise.\n\n**3. Cognitive Abilities and Learning:**\n\n* **Impressive Vocal Learning:** Parrots are exceptional vocal learners, meaning they have the biological capacity to acquire new sounds and incorporate them into their repertoire. This is a rare ability in the animal kingdom, shared with a few other species like songbirds and cetaceans.\n* **Intelligence and Problem-Solving:** Parrots are known for their intelligence and problem-solving skills. This cognitive capacity allows them to understand the context of sounds and learn to associate them with specific meanings or outcomes.\n* **Desire for Stimulation and Attention:** In captivity, parrots often mimic human speech because they are intelligent and crave mental stimulation and social interaction. They learn that making these sounds often gets them attention from their human companions.\n\n**4. Why They Mimic Humans (especially in captivity):**\n\n* **Attention and Reward:** When a parrot makes a sound that a human reacts to positively (with laughter, praise, or a treat), the parrot learns that this behavior is rewarding. They will then repeat it to get that positive reinforcement.\n* **Curiosity and Exploration:** Parrots are naturally curious and explore their environment through all their senses, including sound. They are fascinated by the novel sounds humans make.\n* **Social Integration:** By mimicking human speech, parrots are essentially trying to integrate themselves into their "flock" – their human family. They are trying to communicate and connect on a level they understand.\n* **No Innate Understanding of Meaning (initially):** It\'s important to note that parrots don\'t inherently understand the meaning of the words they say in the same way humans do. They are primarily mimicking sounds and associating them with specific contexts or outcomes. However, some highly intelligent parrots can learn to associate words with objects or actions.\n\n**In summary, parrots talk because:**\n\n* **It\'s a fundamental part of their natural social behavior for communication and bonding.**\n* **They possess remarkable vocal learning abilities, allowing them to acquire new sounds.**\n* **Their intelligence enables them to learn and associate sounds with contexts and rewards.**\n* **In captivity, they mimic human speech to seek attention, stimulation, and to integrate  ...
